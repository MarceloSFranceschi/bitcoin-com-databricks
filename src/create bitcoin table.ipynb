# %%
# %sql
CREATE CATALOG IF NOT EXISTS crypto_coins
COMMENT 'Catálogo para criação de tabela com dados de cryto coins';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS crypto_coins.bitcoin_data
COMMENT 'Schema para armazenar dados de Bitcoin';

# %%
# %sql
select * from crypto_coins.bitcoin_data.bitcoin_price_hist
